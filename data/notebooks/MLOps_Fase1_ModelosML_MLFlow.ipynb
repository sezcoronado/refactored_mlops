# %% [markdown]
# # Clasificación de Niveles de Obesidad — Pipeline completo
# **Descripción:** Notebook que carga `dataset_limpio.csv` (Generado en notebook EDA), realiza preprocesamiento, entrena y compara **RandomForest** y **XGBoost**, ajusta hiperparámetros, evalúa modelos y guarda el mejor pipeline.

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: mlflow-skinny==3.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.0)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (43.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.12.4)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.12/dist-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.43)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.67.0)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.118.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: packaging<26 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.1.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.37.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<46,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: authlib>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.28.1)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.16.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (13.9.4)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<46,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (25.4.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (2.38.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow) (0.48.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow) (3.23.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.4.2)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (3.0.2)
# Requirement already satisfied: isodate in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.3.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: parse in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.20.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.19.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.8.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (4.9.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.27.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.12.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.21.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.6.1)

# %%
# Instalar ngrok y MLflow
# !pip install pyngrok mlflow
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.4.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: mlflow-skinny==3.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.0)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (43.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.12.4)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.12/dist-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.43)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.67.0)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.118.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: packaging<26 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (1.1.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.4.0->mlflow) (0.37.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<46,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: authlib>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.28.1)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.16.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<3,>=2.0.0->mlflow) (13.9.4)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<46,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (25.4.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (2.38.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow) (0.48.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow) (3.23.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.4.2)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (3.0.2)
# Requirement already satisfied: isodate in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.3.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: parse in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.20.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.19.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.8.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (4.9.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.27.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.12.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.21.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.6.1)
# Downloading pyngrok-7.4.0-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.4.0

# %%
import joblib
import mlflow
import os
import subprocess
import mlflow.sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pyngrok import ngrok
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, learning_curve, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from mlflow.models import infer_signature
from google.colab import userdata, files

print('Librerías cargadas correctamente.')
# Out:
# Librerías cargadas correctamente.

# %%
# Configuración Inicial de MLflow
mlflow.set_experiment("Clasificacion_Niveles_Obesidad_RF")
# Out:
# <Experiment: artifact_location='file:///content/mlruns/591922849470545044', creation_time=1760273392175, experiment_id='591922849470545044', last_update_time=1760273392175, lifecycle_stage='active', name='Clasificacion_Niveles_Obesidad_RF', tags={}>

# %%
path = 'dataset_limpio.csv'
df = pd.read_csv(path)


print('Dimensiones:', df.shape)
display(df.head())
# Out:
# Dimensiones: (2153, 17)
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        normal_weight
# 1  Public_Transportation        normal_weight
# 2  Public_Transportation        normal_weight
# 3                Walking   overweight_level_i
# 4  Public_Transportation  overweight_level_ii

# %%
# Inspección rápida
print(df.info())
print('\nDistribución por columnas:\n', df.describe(include='all').T)

# Detectar columna objetivo
target_col = 'NObeyesdad' if 'NObeyesdad' in df.columns else df.columns[-1]
print('\nColumna objetivo asumida:', target_col)

# Codificar target
if df[target_col].dtype == 'object' or str(df[target_col].dtype).startswith('category'):
    # Convertir a tipo category y obtener los nombres de las categorías
    df[target_col] = df[target_col].astype('category')
    clases_reales = df[target_col].cat.categories
    # Convertir a códigos numéricos para el entrenamiento
    df[target_col] = df[target_col].astype('category').cat.codes
    print('Objetivo codificado. Clases:', df[target_col].unique())
    print('Nombres de Clases (clases_reales):', clases_reales.tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2153 entries, 0 to 2152
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2153 non-null   object
#  1   Age                             2153 non-null   float64
#  2   Height                          2153 non-null   float64
#  3   Weight                          2153 non-null   float64
#  4   family_history_with_overweight  2153 non-null   object
#  5   FAVC                            2153 non-null   object
#  6   FCVC                            2153 non-null   float64
#  7   NCP                             2153 non-null   float64
#  8   CAEC                            2153 non-null   object
#  9   SMOKE                           2153 non-null   object
#  10  CH2O                            2153 non-null   float64
#  11  SCC                             2153 non-null   object
#  12  FAF                             2153 non-null   float64
#  13  TUE                             2153 non-null   float64
#  14  CALC                            2153 non-null   object
#  15  MTRANS                          2153 non-null   object
#  16  NObeyesdad                      2153 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 286.1+ KB
# None
#
# Distribución por columnas:
#                                   count unique                    top  freq  \
# Gender                            2153      2                   Male  1109
# Age                             2153.0    NaN                    NaN   NaN
# Height                          2153.0    NaN                    NaN   NaN
# Weight                          2153.0    NaN                    NaN   NaN
# family_history_with_overweight    2153      2                    yes  1769
# FAVC                              2153      2                    yes  1907
# FCVC                            2153.0    NaN                    NaN   NaN
# NCP                             2153.0    NaN                    NaN   NaN
# CAEC                              2153      4              Sometimes  1804
# SMOKE                             2153      2                     no  2109
# CH2O                            2153.0    NaN                    NaN   NaN
# SCC                               2153      2                     no  2055
# FAF                             2153.0    NaN                    NaN   NaN
# TUE                             2153.0    NaN                    NaN   NaN
# CALC                              2153      4              Sometimes  1443
# MTRANS                            2153      5  Public_Transportation  1617
# NObeyesdad                        2153      7         obesity_type_i   375
#
#                                      mean        std   min       25%  \
# Gender                                NaN        NaN   NaN       NaN
# Age                             24.309703   6.273426  14.0      20.0
# Height                           1.702798   0.091999  1.45  1.632605
# Weight                          86.574597  25.804808  39.0      66.4
# family_history_with_overweight        NaN        NaN   NaN       NaN
# FAVC                                  NaN        NaN   NaN       NaN
# FCVC                             2.419897   0.528017   1.0       2.0
# NCP                              2.690983   0.765581   1.0  2.692889
# CAEC                                  NaN        NaN   NaN       NaN
# SMOKE                                 NaN        NaN   NaN       NaN
# CH2O                             2.010886   0.607008   1.0  1.618189
# SCC                                   NaN        NaN   NaN       NaN
# FAF                              1.014012   0.837874   0.0  0.155579
# TUE                              0.653385   0.600209   0.0       0.0
# CALC                                  NaN        NaN   NaN       NaN
# MTRANS                                NaN        NaN   NaN       NaN
# NObeyesdad                            NaN        NaN   NaN       NaN
#
#                                       50%        75%    max
# Gender                                NaN        NaN    NaN
# Age                             22.851773       26.0   61.0
# Height                           1.703584   1.768231   1.98
# Weight                            83.3258  106.49141  173.0
# family_history_with_overweight        NaN        NaN    NaN
# FAVC                                  NaN        NaN    NaN
# FCVC                             2.401603        3.0    3.0
# NCP                                   3.0        3.0    4.0
# CAEC                                  NaN        NaN    NaN
# SMOKE                                 NaN        NaN    NaN
# CH2O                                  2.0   2.471721    3.0
# SCC                                   NaN        NaN    NaN
# FAF                                   1.0   1.637368    3.0
# TUE                              0.628059        1.0    2.0
# CALC                                  NaN        NaN    NaN
# MTRANS                                NaN        NaN    NaN
# NObeyesdad                            NaN        NaN    NaN
#
# Columna objetivo asumida: NObeyesdad
# Objetivo codificado. Clases: [1 5 6 2 0 3 4]
# Nombres de Clases (clases_reales): ['insufficient_weight', 'normal_weight', 'obesity_type_i', 'obesity_type_ii', 'obesity_type_iii', 'overweight_level_i', 'overweight_level_ii']

# %%
# Feature engineering: crear IMC (BMI)
if set(['Height','Weight']).issubset(df.columns):
    df['BMI'] = df['Weight'] / ((df['Height']/100)**2)
    print('Se creó la variable BMI.')
else:
    print('Height/Weight no encontrados; saltando creación de BMI.')

display(df.head())
# Out:
# Se creó la variable BMI.
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS  NObeyesdad            BMI
# 0  Public_Transportation           1  243865.264441
# 1  Public_Transportation           1  242382.271468
# 2  Public_Transportation           1  237654.320988
# 3                Walking           5  268518.518519
# 4  Public_Transportation           6  283423.810125

# %%
# Preparar X,y & preprocesamiento
mapping_names = {i: f"{i}-{name}" for i, name in enumerate(clases_reales)}
X = df.drop(columns=[target_col])
y = df[target_col]

num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = X.select_dtypes(include=['object','category','bool']).columns.tolist()

print('Numéricas:', num_cols)
print('Categóricas:', cat_cols)

num_pipe = Pipeline([('imputer', SimpleImputer(strategy='median')), ('scaler', StandardScaler())])
cat_pipe = Pipeline([('imputer', SimpleImputer(strategy='most_frequent')), ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])
preproc = ColumnTransformer([('num', num_pipe, num_cols), ('cat', cat_pipe, cat_cols)], remainder='drop')
# Out:
# Numéricas: ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE', 'BMI']
# Categóricas: ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']

# %%
# División train/test estratificada
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
print('Train:', X_train.shape, 'Test:', X_test.shape)
print('\nDistribución (train):\n', pd.Series(y_train).map(mapping_names).value_counts(normalize=True))
# Out:
# Train: (1722, 17) Test: (431, 17)
#
# Distribución (train):
#  NObeyesdad
# 2-obesity_type_i         0.174216
# 4-obesity_type_iii       0.151568
# 3-obesity_type_ii        0.140534
# 5-overweight_level_i     0.137631
# 6-overweight_level_ii    0.135889
# 1-normal_weight          0.133566
# 0-insufficient_weight    0.126597
# Name: proportion, dtype: float64

# %%
# RandomForest baseline
target_names_format = [f"{i}-{name}" for i, name in enumerate(clases_reales)]
rf_pipe = Pipeline([('pre', preproc),
                    ('clf', RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42, class_weight='balanced'))])
# MLFLOW START: RandomForest
with mlflow.start_run(run_name="RandomForest_Baseline"):
    mlflow.log_param("model_type", "RandomForest")
    # Registra los hiperparámetros del clasificador
    mlflow.log_params(rf_pipe.named_steps['clf'].get_params())
    mlflow.log_param("smote_applied", False)

    rf_pipe.fit(X_train, y_train)
    pred_rf = rf_pipe.predict(X_test)

    # 1. Log Metrics: Accuracy y Classification Report (weighted avg)
    accuracy = accuracy_score(y_test, pred_rf)
    # Usamos output_dict=True para capturar métricas programáticamente
    report = classification_report(y_test, pred_rf, target_names=target_names_format, output_dict=True)

    mlflow.log_metric("test_accuracy", accuracy)
    mlflow.log_metric("rf_precision_weighted", report['weighted avg']['precision'])
    mlflow.log_metric("rf_recall_weighted", report['weighted avg']['recall'])
    mlflow.log_metric("rf_f1_weighted", report['weighted avg']['f1-score'])

    # 2. Log Underfitting/Overfitting Metrics (Se loggea el score del pipe)
    train_score = rf_pipe.score(X_train, y_train)
    test_score = rf_pipe.score(X_test, y_test)
    gap = train_score - test_score

    mlflow.log_metric("train_score", train_score)
    mlflow.log_metric("test_score_ov_uf", test_score)
    mlflow.log_metric("gap_overfitting", gap)

    # Log model y la firma
    mlflow.sklearn.log_model(rf_pipe, "random_forest_model", signature=infer_signature(X_test, pred_rf))

    print('RandomForest - Accuracy:', accuracy)
    print()
    print(classification_report(y_test, pred_rf, target_names=target_names_format))
    print()
    print('Confusion matrix:\\n', confusion_matrix(y_test, pred_rf))
#MLFLOW END: RandomForest
# Out:
# 2025/10/12 13:49:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# RandomForest - Accuracy: 0.9582366589327146
#
#                        precision    recall  f1-score   support
#
# 0-insufficient_weight       0.98      0.98      0.98        54
#       1-normal_weight       0.90      0.98      0.94        58
#      2-obesity_type_i       0.96      0.91      0.93        75
#     3-obesity_type_ii       0.98      0.97      0.98        61
#    4-obesity_type_iii       0.97      0.97      0.97        65
#  5-overweight_level_i       0.97      0.97      0.97        60
# 6-overweight_level_ii       0.95      0.95      0.95        58
#
#              accuracy                           0.96       431
#             macro avg       0.96      0.96      0.96       431
#          weighted avg       0.96      0.96      0.96       431
#
#
# Confusion matrix:\n [[53  1  0  0  0  0  0]
#  [ 1 57  0  0  0  0  0]
#  [ 0  2 68  0  1  1  3]
#  [ 0  1  0 59  1  0  0]
#  [ 0  0  1  1 63  0  0]
#  [ 0  1  1  0  0 58  0]
#  [ 0  1  1  0  0  1 55]]

# %%
# XGBoost con SMOTE y RandomizedSearchCV
#num_classes = len(np.unique(y))
xgb_pipe_smote = ImbPipeline([('pre', preproc),
                        ('smote', SMOTE(random_state=42)),
                        ('clf', XGBClassifier(objective='multi:softprob',
                                              #use_label_encoder=False,
                                              eval_metric='mlogloss',
                                              random_state=42))#,
                                              #num_class=num_classes))
                        ])

param_dist = {
    'clf__n_estimators': [100, 200, 400],
    'clf__max_depth': [3, 5, 7],
    'clf__learning_rate': [0.01, 0.05, 0.1],
    'clf__subsample': [0.6, 0.8, 1.0],
    'clf__colsample_bytree': [0.6, 0.8, 1.0],
    'smote__k_neighbors': [1]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

search = RandomizedSearchCV(xgb_pipe_smote,
                            param_dist,
                            n_iter=20,
                            scoring='accuracy',
                            n_jobs=-1,
                            cv=cv,
                            random_state=42,
                            verbose=2)
print('Iniciando búsqueda aleatoria XGBoost.\n')

search.fit(X_train, y_train)
best_xgb = search.best_estimator_
pred_xgb = best_xgb.predict(X_test)
print('\nMejores parámetros:', search.best_params_)

# MLFLOW START: XGBoost (SMOTE)
with mlflow.start_run(run_name="XGBoost_SMOTE_Tuning"):
    mlflow.log_param("model_type", "XGBoost_SMOTE")
    # Registra los mejores hiperparámetros encontrados
    mlflow.log_params(search.best_params_)

    # 1. Log Metrics: Accuracy y Classification Report (weighted avg)
    accuracy = accuracy_score(y_test, pred_xgb)
    report = classification_report(y_test, pred_xgb, target_names=target_names_format, output_dict=True)

    mlflow.log_metric("test_accuracy", accuracy)
    mlflow.log_metric("xgb_smote_precision_weighted", report['weighted avg']['precision'])
    mlflow.log_metric("xgb_smote_recall_weighted", report['weighted avg']['recall'])
    mlflow.log_metric("xgb_smote_f1_weighted", report['weighted avg']['f1-score'])

    # 2. Log Underfitting/Overfitting Metrics
    train_score = best_xgb.score(X_train, y_train)
    test_score = best_xgb.score(X_test, y_test)
    gap = train_score - test_score

    mlflow.log_metric("train_score", train_score)
    mlflow.log_metric("test_score_ov_uf", test_score)
    mlflow.log_metric("gap_overfitting", gap)

    # Log model y la firma
    mlflow.sklearn.log_model(best_xgb, "xgboost_smote_model", signature=infer_signature(X_test, pred_xgb))

    print('\nXGBoost - Accuracy:', accuracy)
    print()
    print(classification_report(y_test, pred_xgb, target_names=target_names_format))
    print()
    print('Confusion matrix:\\n', confusion_matrix(y_test, pred_xgb))
# MLFLOW END: XGBoost (SMOTE)
# Out:
# Iniciando búsqueda aleatoria XGBoost.
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 2025/10/12 13:52:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Mejores parámetros: {'smote__k_neighbors': 1, 'clf__subsample': 0.6, 'clf__n_estimators': 200, 'clf__max_depth': 5, 'clf__learning_rate': 0.1, 'clf__colsample_bytree': 0.6}
#
# XGBoost - Accuracy: 0.9698375870069605
#
#                        precision    recall  f1-score   support
#
# 0-insufficient_weight       0.98      0.98      0.98        54
#       1-normal_weight       0.95      0.98      0.97        58
#      2-obesity_type_i       0.97      0.92      0.95        75
#     3-obesity_type_ii       0.98      0.97      0.98        61
#    4-obesity_type_iii       0.97      0.98      0.98        65
#  5-overweight_level_i       0.97      0.98      0.98        60
# 6-overweight_level_ii       0.97      0.98      0.97        58
#
#              accuracy                           0.97       431
#             macro avg       0.97      0.97      0.97       431
#          weighted avg       0.97      0.97      0.97       431
#
#
# Confusion matrix:\n [[53  1  0  0  0  0  0]
#  [ 1 57  0  0  0  0  0]
#  [ 0  1 69  0  1  2  2]
#  [ 0  1  0 59  1  0  0]
#  [ 0  0  0  1 64  0  0]
#  [ 0  0  1  0  0 59  0]
#  [ 0  0  1  0  0  0 57]]

# %%
#XGBoost sin SMOTE
#Extraer los mejores parámetros de XGBoost de la búsqueda anterior
best_params_xgb = {
    k.replace('clf__', ''): v
    for k, v in search.best_params_.items()
    if k.startswith('clf__') and 'k_neighbors' not in k
}

#Entrenar el pipeline sin SMOTE
xgb_simple_pipe = Pipeline(steps=[
    ('pre', preproc),
    ('clf', XGBClassifier(
        **best_params_xgb, # Apply the learned parameters
        objective='multi:softprob',
        eval_metric='mlogloss',
        random_state=42             # Ensure reproducibility
    ))
])


# MLFLOW START: XGBoost (sin SMOTE)
with mlflow.start_run(run_name="XGBoost_NoSMOTE_BestParams"):
    mlflow.log_param("model_type", "XGBoost_NoSMOTE")
    mlflow.log_params(best_params_xgb)
    mlflow.log_param("smote_applied", False)

    xgb_simple_pipe.fit(X_train, y_train)

    # Evaluar el modelo sin SMOTE
    pred_xgb_simple = xgb_simple_pipe.predict(X_test)

    # 1. Log Metrics: Accuracy y Classification Report (weighted avg)
    accuracy = accuracy_score(y_test, pred_xgb_simple)
    report = classification_report(y_test, pred_xgb_simple, target_names=target_names_format, output_dict=True)

    mlflow.log_metric("test_accuracy", accuracy)
    mlflow.log_metric("xgb_simple_precision_weighted", report['weighted avg']['precision'])
    mlflow.log_metric("xgb_simple_recall_weighted", report['weighted avg']['recall'])
    mlflow.log_metric("xgb_simple_f1_weighted", report['weighted avg']['f1-score'])

    # 2. Log Underfitting/Overfitting Metrics
    train_score = xgb_simple_pipe.score(X_train, y_train)
    test_score = xgb_simple_pipe.score(X_test, y_test)
    gap = train_score - test_score

    mlflow.log_metric("train_score", train_score)
    mlflow.log_metric("test_score_ov_uf", test_score)
    mlflow.log_metric("gap_overfitting", gap)

    # Log model y la firma
    mlflow.sklearn.log_model(xgb_simple_pipe, "xgboost_simple_model", signature=infer_signature(X_test, pred_xgb_simple))

    # 5. Mostrar resultados
    print('XGBoost sin SMOTE - Accuracy:', accuracy)
    print()
    print(classification_report(y_test, pred_xgb_simple, target_names=target_names_format))
    print()
    print('Matriz de Confusión:\\n', confusion_matrix(y_test, pred_xgb_simple))
# MLFLOW END: XGBoost (sin SMOTE)
# Out:
# 2025/10/12 13:52:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# XGBoost sin SMOTE - Accuracy: 0.9721577726218097
#
#                        precision    recall  f1-score   support
#
# 0-insufficient_weight       0.98      1.00      0.99        54
#       1-normal_weight       0.98      0.98      0.98        58
#      2-obesity_type_i       0.96      0.92      0.94        75
#     3-obesity_type_ii       0.98      0.97      0.98        61
#    4-obesity_type_iii       0.97      0.98      0.98        65
#  5-overweight_level_i       0.97      0.98      0.98        60
# 6-overweight_level_ii       0.97      0.98      0.97        58
#
#              accuracy                           0.97       431
#             macro avg       0.97      0.97      0.97       431
#          weighted avg       0.97      0.97      0.97       431
#
#
# Matriz de Confusión:\n [[54  0  0  0  0  0  0]
#  [ 1 57  0  0  0  0  0]
#  [ 0  1 69  0  1  2  2]
#  [ 0  0  1 59  1  0  0]
#  [ 0  0  0  1 64  0  0]
#  [ 0  0  1  0  0 59  0]
#  [ 0  0  1  0  0  0 57]]

# %%
def train_and_log_classifier(name, classifier, X_train, y_train, X_test, y_test, preproc, target_names_format):
    """Entrena un clasificador, lo evalúa y registra los resultados en MLflow."""

    # 1. Crear Pipeline
    pipe = Pipeline([
        ('pre', preproc),
        ('clf', classifier)
    ])

    # MLFLOW START: Nuevo Modelo
    with mlflow.start_run(run_name=f"{name}_Classifier_Baseline"):
        mlflow.log_param("model_type", name)
        mlflow.log_param("smote_applied", False)

        # Registra los hiperparámetros iniciales
        mlflow.log_params(classifier.get_params())

        # 2. Entrenamiento y Predicción
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)

        # 3. Log Metrics: Accuracy y Classification Report (weighted avg)
        accuracy = accuracy_score(y_test, y_pred)
        # Usamos output_dict=True para capturar métricas programáticamente
        report = classification_report(y_test, y_pred, target_names=target_names_format, output_dict=True)

        mlflow.log_metric("test_accuracy", accuracy)
        mlflow.log_metric(f"{name.lower()}_precision_weighted", report['weighted avg']['precision'])
        mlflow.log_metric(f"{name.lower()}_recall_weighted", report['weighted avg']['recall'])
        mlflow.log_metric(f"{name.lower()}_f1_weighted", report['weighted avg']['f1-score'])

        # 4. Log Underfitting/Overfitting Metrics
        train_score = pipe.score(X_train, y_train)
        test_score = pipe.score(X_test, y_test)
        gap = train_score - test_score

        mlflow.log_metric("train_score", train_score)
        mlflow.log_metric("test_score_ov_uf", test_score)
        mlflow.log_metric("gap_overfitting", gap)

        # 5. Log model y la firma
        mlflow.sklearn.log_model(pipe, f"{name.lower()}_model", signature=infer_signature(X_test, y_pred))

        print(f'{name} - Accuracy: {accuracy_score(y_test, y_pred):.4f}')
        print(f"  Score en entrenamiento: {train_score:.4f}")
        print(f"  Score en prueba:        {test_score:.4f}")
        print(f"  Diferencia (gap):       {gap:.4f}")
        print('-' * 40)
    #MLFLOW END

    return pipe, y_pred

# K-Nearest Neighbors (KNN)
knn_pipe, pred_knn = train_and_log_classifier(
    "KNN",
    KNeighborsClassifier(n_neighbors=5),  # n_neighbors=5 como baseline
    X_train, y_train, X_test, y_test, preproc, target_names_format
)

# Support Vector Machine (Linear Kernel)
# Se utiliza un SVC con kernel lineal para un modelo simple y escalable.
svm_pipe, pred_svm = train_and_log_classifier(
    "SVM_Linear",
    SVC(kernel='linear', C=1.0, random_state=42),
    X_train, y_train, X_test, y_test, preproc, target_names_format
)
# Out:
# 2025/10/12 13:52:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# KNN - Accuracy: 0.8561
#   Score en entrenamiento: 0.9007
#   Score en prueba:        0.8561
#   Diferencia (gap):       0.0445
# ----------------------------------------
# 2025/10/12 13:52:16 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# SVM_Linear - Accuracy: 0.9211
#   Score en entrenamiento: 0.9431
#   Score en prueba:        0.9211
#   Diferencia (gap):       0.0220
# ----------------------------------------

# %%
# Comparar y guardar
acc_rf = accuracy_score(y_test, pred_rf)
acc_xgb = accuracy_score(y_test, pred_xgb)
acc_xgb_simple = accuracy_score(y_test, pred_xgb_simple)
acc_knn = accuracy_score(y_test, pred_knn)
acc_svm = accuracy_score(y_test, pred_svm)

# Lógica para determinar el mejor modelo general
model_accuracies = {
    'RandomForest': acc_rf,
    'XGBoost (SMOTE)': acc_xgb,
    'XGBoost (sin SMOTE)': acc_xgb_simple,
    'KNN': acc_knn,
    'SVM_Linear': acc_svm
}

best_name = max(model_accuracies, key=model_accuracies.get)
best_acc = model_accuracies[best_name]

# Asignar el mejor pipeline para guardar
if best_name == 'RandomForest':
    best_model = rf_pipe
elif best_name == 'XGBoost (SMOTE)':
    # Recordar que 'best_xgb' es el objeto pipeline de imblearn
    best_model = best_xgb
elif best_name == 'XGBoost (sin SMOTE)':
    best_model = xgb_simple_pipe
elif best_name == 'KNN':
    best_model = knn_pipe
elif best_name == 'SVM_Linear':
    best_model = svm_pipe


print('Mejor modelo:', best_name, 'Accuracy:', best_acc)
joblib.dump(best_model, 'best_pipeline.joblib')
print('Pipeline guardado en best_pipeline.joblib')
# Out:
# Mejor modelo: XGBoost (sin SMOTE) Accuracy: 0.9721577726218097
# Pipeline guardado en best_pipeline.joblib

# %%
# Crear DataFrame de métricas comparativas
metrics_df = pd.DataFrame({
    'Modelo': ['RandomForest', 'XGBoost(Smote)', 'XGBoost(sin SMOTE)', 'KNN', 'SVM_Linear'],
    'Accuracy': [accuracy_score(y_test, pred_rf),
                 accuracy_score(y_test, pred_xgb),
                 accuracy_score(y_test, pred_xgb_simple),
                 accuracy_score(y_test, pred_knn), # Nuevo
                 accuracy_score(y_test, pred_svm)], # Nuevo
    'Precision': [precision_score(y_test, pred_rf, average='weighted'),
                  precision_score(y_test, pred_xgb, average='weighted'),
                  precision_score(y_test, pred_xgb_simple, average='weighted'),
                  precision_score(y_test, pred_knn, average='weighted'), # Nuevo
                  precision_score(y_test, pred_svm, average='weighted')], # Nuevo
    'Recall': [recall_score(y_test, pred_rf, average='weighted'),
               recall_score(y_test, pred_xgb, average='weighted'),
               recall_score(y_test, pred_xgb_simple, average='weighted'),
               recall_score(y_test, pred_knn, average='weighted'), # Nuevo
               recall_score(y_test, pred_svm, average='weighted')], # Nuevo
    'F1-score': [f1_score(y_test, pred_rf, average='weighted'),
                 f1_score(y_test, pred_xgb, average='weighted'),
                 f1_score(y_test, pred_xgb_simple, average='weighted'),
                 f1_score(y_test, pred_knn, average='weighted'), # Nuevo
                 f1_score(y_test, pred_svm, average='weighted')] # Nuevo
})

# Gráfico de barras comparativo
plt.figure(figsize=(10,6)) # Aumentar un poco el tamaño para más barras
metrics_df.set_index('Modelo').plot(kind='bar', ax=plt.gca(), colormap='viridis')
plt.title('Comparación de métricas de rendimiento')
plt.ylabel('Valor')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor visualización
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout() # Ajustar diseño
plt.show()

display(metrics_df)
# Out:
#                Modelo  Accuracy  Precision    Recall  F1-score
# 0        RandomForest  0.958237   0.958911  0.958237  0.958226
# 1      XGBoost(Smote)  0.969838   0.969995  0.969838  0.969718
# 2  XGBoost(sin SMOTE)  0.972158   0.972096  0.972158  0.972012
# 3                 KNN  0.856148   0.859168  0.856148  0.850265
# 4          SVM_Linear  0.921114   0.923676  0.921114  0.920226

# %%
# Matrices de confusión
fig, axes = plt.subplots(5, 1, figsize=(10, 25)) # Aumentamos el tamaño vertical (25) y el número de filas (5)

# RandomForest
sns.heatmap(confusion_matrix(y_test, pred_rf),
            annot=True,
            fmt='d',
            cmap='Blues',
            ax=axes[0],
            xticklabels=clases_reales,
            yticklabels=clases_reales)
axes[0].set_title('Matriz de confusión - RandomForest')
axes[0].set_xlabel('Predicho')
axes[0].set_ylabel('Real')

# XGBoost (SMOTE)
sns.heatmap(confusion_matrix(y_test, pred_xgb),
            annot=True, fmt='d',
            cmap='Greens',
            ax=axes[1],
            xticklabels=clases_reales,
            yticklabels=clases_reales)
axes[1].set_title('\n\nMatriz de confusión - XGBoost(SMOTE)')
axes[1].set_xlabel('Predicho')
axes[1].set_ylabel('Real')

# XGBoost (sin SMOTE)
sns.heatmap(confusion_matrix(y_test, pred_xgb_simple),
            annot=True, fmt='d',
            cmap='Reds',
            ax=axes[2],
            xticklabels=clases_reales,
            yticklabels=clases_reales)
axes[2].set_title('\n\nMatriz de confusión - XGBoost(sin SMOTE)')
axes[2].set_xlabel('Predicho')
axes[2].set_ylabel('Real')

# 4. KNN
sns.heatmap(confusion_matrix(y_test, pred_knn),
            annot=True, fmt='d',
            cmap='Purples',
            ax=axes[3],
            xticklabels=clases_reales,
            yticklabels=clases_reales)
axes[3].set_title('\n\nMatriz de confusión - K-Nearest Neighbors (KNN)')
axes[3].set_xlabel('Predicho')
axes[3].set_ylabel('Real')

# SVM_Linear
sns.heatmap(confusion_matrix(y_test, pred_svm),
            annot=True, fmt='d',
            cmap='Oranges',
            ax=axes[4],
            xticklabels=clases_reales,
            yticklabels=clases_reales)
axes[4].set_title('\n\nMatriz de confusión - SVM (Linear)')
axes[4].set_xlabel('Predicho')
axes[4].set_ylabel('Real')


plt.tight_layout()
plt.show()

# %%
# Evaluar overfitting / underfitting
def evaluar_overfitting(modelo, X_train, X_test, y_train, y_test, nombre):
    """Calcula y muestra el gap de rendimiento entre train y test."""

    # Nota: Usamos el método .score() que es el accuracy en clasificación para pipelines
    train_score = modelo.score(X_train, y_train)
    test_score = modelo.score(X_test, y_test)
    gap = train_score - test_score

    print(f'\nModelo: {nombre}')
    print(f'  Score en entrenamiento: {train_score:.3f}')
    print(f'  Score en prueba:        {test_score:.3f}')
    print(f'  Diferencia (gap):       {gap:.3f}')

    if gap > 0.1:
        print("Posible sobreajuste (overfitting).")
    elif gap < -0.05:
        print("Posible bajoajuste (underfitting).")
    else:
        print("Ajuste adecuado (sin evidencia fuerte de over/underfitting).")

# Evaluación de los modelos originales
evaluar_overfitting(rf_pipe, X_train, X_test, y_train, y_test, "RandomForest")
evaluar_overfitting(best_xgb, X_train, X_test, y_train, y_test, "XGBoost (SMOTE)")
evaluar_overfitting(xgb_simple_pipe, X_train, X_test, y_train, y_test, "XGBoost (sin SMOTE)")
evaluar_overfitting(knn_pipe, X_train, X_test, y_train, y_test, "KNN")
evaluar_overfitting(svm_pipe, X_train, X_test, y_train, y_test, "SVM_Linear")
# Out:
# Modelo: RandomForest
#   Score en entrenamiento: 0.992
#   Score en prueba:        0.958
#   Diferencia (gap):       0.034
# Ajuste adecuado (sin evidencia fuerte de over/underfitting).
#
# Modelo: XGBoost (SMOTE)
#   Score en entrenamiento: 0.999
#   Score en prueba:        0.970
#   Diferencia (gap):       0.030
# Ajuste adecuado (sin evidencia fuerte de over/underfitting).
#
# Modelo: XGBoost (sin SMOTE)
#   Score en entrenamiento: 0.999
#   Score en prueba:        0.972
#   Diferencia (gap):       0.027
# Ajuste adecuado (sin evidencia fuerte de over/underfitting).
#
# Modelo: KNN
#   Score en entrenamiento: 0.901
#   Score en prueba:        0.856
#   Diferencia (gap):       0.045
# Ajuste adecuado (sin evidencia fuerte de over/underfitting).
#
# Modelo: SVM_Linear
#   Score en entrenamiento: 0.943
#   Score en prueba:        0.921
#   Diferencia (gap):       0.022
# Ajuste adecuado (sin evidencia fuerte de over/underfitting).

# %%
# Verificar la URI de seguimiento
print(f"Tracking URI: {mlflow.get_tracking_uri()}")
# Out:
# Tracking URI: file:///content/mlruns

# %%
# !zip -r mlruns.zip mlruns/
# Out:
#   adding: mlruns/ (stored 0%)
#   adding: mlruns/0/ (stored 0%)
#   adding: mlruns/0/meta.yaml (deflated 24%)
#   adding: mlruns/.trash/ (stored 0%)
#   adding: mlruns/591922849470545044/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/n_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/metric_params (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/p (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/algorithm (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/weights (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/metric (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/params/leaf_size (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/outputs/m-98d93047cadb4174adba7cdc461a0cde/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/outputs/m-98d93047cadb4174adba7cdc461a0cde/meta.yaml (deflated 37%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/knn_f1_weighted (deflated 46%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/knn_precision_weighted (deflated 46%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/gap_overfitting (deflated 45%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/test_accuracy (deflated 43%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/train_score (deflated 43%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/test_score_ov_uf (deflated 44%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/metrics/knn_recall_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/meta.yaml (deflated 39%)
#   adding: mlruns/591922849470545044/6723ab5f0be14ff68f3b9973b507cb23/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/decision_function_shape (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/cache_size (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/max_iter (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/tol (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/coef0 (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/gamma (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/degree (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/kernel (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/C (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/break_ties (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/shrinking (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/params/probability (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/outputs/m-9bbecccc2e6e4cdfbada9b3885670618/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/outputs/m-9bbecccc2e6e4cdfbada9b3885670618/meta.yaml (deflated 37%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/svm_linear_precision_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/gap_overfitting (deflated 43%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/test_accuracy (deflated 44%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/svm_linear_recall_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/train_score (deflated 53%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/test_score_ov_uf (deflated 44%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/metrics/svm_linear_f1_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/meta.yaml (deflated 38%)
#   adding: mlruns/591922849470545044/c4924335bcf94965a7a5c28a9cff00b5/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/decision_function_shape (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/cache_size (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/max_iter (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/tol (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/coef0 (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/gamma (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/degree (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/kernel (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/C (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/break_ties (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/shrinking (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/params/probability (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/outputs/m-09068ccf342f46f3b6fa65b60a86138d/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/outputs/m-09068ccf342f46f3b6fa65b60a86138d/meta.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/svm_linear_precision_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/gap_overfitting (deflated 43%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/test_accuracy (deflated 44%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/svm_linear_recall_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/train_score (deflated 53%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/test_score_ov_uf (deflated 44%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/metrics/svm_linear_f1_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/meta.yaml (deflated 39%)
#   adding: mlruns/591922849470545044/2bdb41d57e544afb8061101fa8c1aaef/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/smote__k_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/clf__max_depth (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/clf__learning_rate (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/clf__subsample (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/clf__n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/params/clf__colsample_bytree (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/outputs/m-7260ebd16e4e4a0bacbbe3267fc01cb5/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/outputs/m-7260ebd16e4e4a0bacbbe3267fc01cb5/meta.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/xgb_smote_precision_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/xgb_smote_f1_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/gap_overfitting (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/test_accuracy (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/train_score (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/test_score_ov_uf (deflated 44%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/metrics/xgb_smote_recall_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/meta.yaml (deflated 38%)
#   adding: mlruns/591922849470545044/e66b65800e2a48a0ab93fcb74bd83065/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/smote__k_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/clf__max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/clf__learning_rate (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/clf__subsample (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/clf__n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/params/clf__colsample_bytree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/xgb_smote_precision_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/xgb_smote_f1_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/gap_overfitting (deflated 16%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/test_accuracy (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/train_score (deflated 16%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/test_score_ov_uf (deflated 16%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/metrics/xgb_smote_recall_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/requirements.txt (deflated 24%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/model.pkl (deflated 77%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/conda.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/models/m-2268590dbb1c4f31b37ad8728e5dbbba/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/smote__k_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/clf__max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/clf__learning_rate (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/clf__subsample (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/clf__n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/params/clf__colsample_bytree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/xgb_smote_precision_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/xgb_smote_f1_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/gap_overfitting (deflated 16%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/test_accuracy (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/test_score_ov_uf (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/metrics/xgb_smote_recall_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/requirements.txt (deflated 24%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/model.pkl (deflated 77%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/conda.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/models/m-7260ebd16e4e4a0bacbbe3267fc01cb5/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/colsample_bytree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/learning_rate (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/params/subsample (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/xgb_simple_recall_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/gap_overfitting (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/test_accuracy (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/xgb_simple_precision_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/train_score (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/test_score_ov_uf (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/metrics/xgb_simple_f1_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/requirements.txt (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/model.pkl (deflated 78%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/conda.yaml (deflated 33%)
#   adding: mlruns/591922849470545044/models/m-de76e46be4fa450caf73410e672e9d74/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/decision_function_shape (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/cache_size (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/max_iter (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/tol (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/coef0 (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/gamma (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/degree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/kernel (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/C (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/break_ties (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/shrinking (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/params/probability (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/svm_linear_precision_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/gap_overfitting (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/test_accuracy (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/svm_linear_recall_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/test_score_ov_uf (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/metrics/svm_linear_f1_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/requirements.txt (deflated 18%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/model.pkl (deflated 80%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/conda.yaml (deflated 32%)
#   adding: mlruns/591922849470545044/models/m-09068ccf342f46f3b6fa65b60a86138d/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/min_samples_leaf (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/min_samples_split (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/warm_start (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/criterion (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/min_impurity_decrease (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/max_samples (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/max_leaf_nodes (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/bootstrap (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/ccp_alpha (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/min_weight_fraction_leaf (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/max_features (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/monotonic_cst (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/params/oob_score (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/gap_overfitting (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/test_accuracy (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/rf_precision_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/test_score_ov_uf (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/rf_recall_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/metrics/rf_f1_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/requirements.txt (deflated 18%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/model.pkl (deflated 72%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/conda.yaml (deflated 32%)
#   adding: mlruns/591922849470545044/models/m-e4146de5f0e7464d8688a2a69840beb1/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/colsample_bytree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/learning_rate (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/params/subsample (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/xgb_simple_recall_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/gap_overfitting (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/test_accuracy (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/xgb_simple_precision_weighted (deflated 10%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/test_score_ov_uf (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/metrics/xgb_simple_f1_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/requirements.txt (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/model.pkl (deflated 78%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/conda.yaml (deflated 33%)
#   adding: mlruns/591922849470545044/models/m-a59e478764384565a0fdf2badd360572/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/min_samples_leaf (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/min_samples_split (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/warm_start (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/criterion (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/min_impurity_decrease (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/max_samples (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/max_leaf_nodes (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/bootstrap (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/ccp_alpha (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/min_weight_fraction_leaf (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/max_features (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/monotonic_cst (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/params/oob_score (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/gap_overfitting (deflated 14%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/test_accuracy (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/rf_precision_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/test_score_ov_uf (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/rf_recall_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/metrics/rf_f1_weighted (deflated 10%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/requirements.txt (deflated 18%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/model.pkl (deflated 72%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/conda.yaml (deflated 32%)
#   adding: mlruns/591922849470545044/models/m-4737896342434699b8cdb97a76893be2/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/n_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/metric_params (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/p (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/algorithm (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/weights (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/metric (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/params/leaf_size (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/knn_f1_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/knn_precision_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/gap_overfitting (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/test_accuracy (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/test_score_ov_uf (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/metrics/knn_recall_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/requirements.txt (deflated 18%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/model.pkl (deflated 78%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/conda.yaml (deflated 32%)
#   adding: mlruns/591922849470545044/models/m-98d93047cadb4174adba7cdc461a0cde/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/decision_function_shape (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/cache_size (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/max_iter (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/tol (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/coef0 (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/gamma (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/degree (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/kernel (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/C (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/break_ties (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/shrinking (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/params/probability (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/svm_linear_precision_weighted (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/gap_overfitting (deflated 14%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/test_accuracy (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/svm_linear_recall_weighted (deflated 13%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/train_score (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/test_score_ov_uf (deflated 12%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/metrics/svm_linear_f1_weighted (deflated 15%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/MLmodel (deflated 65%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/requirements.txt (deflated 18%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/model.pkl (deflated 80%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/conda.yaml (deflated 32%)
#   adding: mlruns/591922849470545044/models/m-9bbecccc2e6e4cdfbada9b3885670618/artifacts/python_env.yaml (deflated 17%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/ (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/n_neighbors (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/metric_params (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/models/m-037f0fc7261949d591756db1e7bc3c38/params/p (stored 0%)
# ...
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/outputs/m-de76e46be4fa450caf73410e672e9d74/ (stored 0%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/outputs/m-de76e46be4fa450caf73410e672e9d74/meta.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/xgb_simple_recall_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/gap_overfitting (deflated 46%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/test_accuracy (deflated 43%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/xgb_simple_precision_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/train_score (deflated 44%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/test_score_ov_uf (deflated 44%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/metrics/xgb_simple_f1_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/meta.yaml (deflated 38%)
#   adding: mlruns/591922849470545044/28babb626a324ec6bc7eec817b828172/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/min_samples_leaf (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/min_samples_split (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/warm_start (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/criterion (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/min_impurity_decrease (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/max_samples (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/max_leaf_nodes (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/bootstrap (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/ccp_alpha (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/min_weight_fraction_leaf (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/max_features (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/monotonic_cst (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/params/oob_score (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/outputs/m-e4146de5f0e7464d8688a2a69840beb1/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/outputs/m-e4146de5f0e7464d8688a2a69840beb1/meta.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/gap_overfitting (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/test_accuracy (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/rf_precision_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/train_score (deflated 53%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/test_score_ov_uf (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/rf_recall_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/metrics/rf_f1_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/meta.yaml (deflated 39%)
#   adding: mlruns/591922849470545044/a1b57a93320d49f4af99ef5a868c289d/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/ (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/params/ (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/meta.yaml (deflated 40%)
#   adding: mlruns/591922849470545044/2b6518dba3b746b8a2defabc7a39d26d/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/ (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/params/ (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/meta.yaml (deflated 41%)
#   adding: mlruns/591922849470545044/b1d962bec12348058c158a886a547568/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/ (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/ (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/min_samples_leaf (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/min_samples_split (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/warm_start (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/criterion (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/min_impurity_decrease (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/max_samples (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/max_leaf_nodes (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/bootstrap (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/ccp_alpha (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/min_weight_fraction_leaf (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/max_features (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/monotonic_cst (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/params/oob_score (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/gap_overfitting (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/test_accuracy (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/rf_precision_weighted (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/train_score (deflated 18%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/test_score_ov_uf (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/rf_recall_weighted (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/metrics/rf_f1_weighted (stored 0%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/meta.yaml (deflated 40%)
#   adding: mlruns/591922849470545044/c71fed73cc2a426dbe91ad24b3f5d60f/artifacts/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/class_weight (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/verbose (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/random_state (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/min_samples_leaf (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/model_type (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/min_samples_split (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/max_depth (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/n_estimators (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/warm_start (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/criterion (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/min_impurity_decrease (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/n_jobs (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/max_samples (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/smote_applied (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/max_leaf_nodes (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/bootstrap (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/ccp_alpha (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/min_weight_fraction_leaf (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/max_features (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/monotonic_cst (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/params/oob_score (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/tags/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/tags/mlflow.source.name (deflated 5%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/tags/mlflow.runName (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/tags/mlflow.user (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/tags/mlflow.source.type (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/outputs/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/outputs/m-4737896342434699b8cdb97a76893be2/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/outputs/m-4737896342434699b8cdb97a76893be2/meta.yaml (deflated 36%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/ (stored 0%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/gap_overfitting (deflated 43%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/test_accuracy (deflated 43%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/rf_precision_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/train_score (deflated 53%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/test_score_ov_uf (deflated 43%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/rf_recall_weighted (deflated 43%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/metrics/rf_f1_weighted (deflated 44%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/meta.yaml (deflated 39%)
#   adding: mlruns/591922849470545044/8c5d46b7faa846889b3ff120b82d52d7/artifacts/ (stored 0%)

# %%
files.download('mlruns.zip')

# %%
NGROK_AUTH_TOKEN = userdata.get('Ez_NGrok')

# %%
# Asegúrate de que el token esté configurado
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Lanza el servidor MLflow en segundo plano
# (Asume que MLflow está guardando los runs en la carpeta 'mlruns' por defecto)
mlflow_command = "mlflow ui"
process = subprocess.Popen(mlflow_command.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Crea un túnel ngrok al puerto 5000 (puerto por defecto de MLflow)
public_url = ngrok.connect(5000)

print(f"MLflow UI disponible en: {public_url}")
# Out:
# MLflow UI disponible en: NgrokTunnel: "https://overvehement-loraine-subchorioid.ngrok-free.dev" -> "http://localhost:5000"
